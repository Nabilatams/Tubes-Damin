# %%
## 📊 Dashboard Overview

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
file_path = "data/Students Performance Dataset.csv"
df = pd.read_csv(file_path)

# Tampilkan 5 data teratas
print("\n▶️ 5 Baris Pertama:")
display(df.head())

# Jumlah data
print("\n▶️ Jumlah Data:")
print(f"Baris: {df.shape[0]}, Kolom: {df.shape[1]}")

# Distribusi nilai kelulusan jika sudah ada kolom 'Class'
if "Class" in df.columns:
    print("\n▶️ Distribusi Kelas:")
    display(df["Class"].value_counts())
    df["Class"].value_counts().plot.pie(autopct="%1.1f%%", startangle=90, colors=["red", "green"])
    plt.title("Distribusi Class (Pass/Fail)")
    plt.ylabel("")
    plt.show()

# Statistik umum
print("\n▶️ Statistik Umum:")
display(df.describe())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1-2403502529.py in <cell line: 0>()
#       7 # Load dataset
#       8 file_path = "data/Students Performance Dataset.csv"
# ----> 9 df = pd.read_csv(file_path)
#      10
#      11 # Tampilkan 5 data teratas
#
# ...
