# %%
## 🌟 Business Understanding

from IPython.display import Markdown, display

display(Markdown("""
### 🌍 Latar Belakang Masalah

Dalam dunia pendidikan, penting bagi lembaga pendidikan untuk memahami faktor-faktor apa saja yang dapat mempengaruhi kelulusan siswa. Dengan memanfaatkan data performa akademik, kita dapat membangun sistem prediksi kelulusan secara otomatis.

### 🎟️ Tujuan Proyek

1. Mengidentifikasi faktor penting yang mempengaruhi kelulusan siswa.
2. Membangun model klasifikasi untuk memprediksi apakah siswa akan *lulus* atau *tidak*.
3. Mengelompokkan siswa berdasarkan pola performa mereka (clustering).

### 🔧 Metode yang Digunakan

- **EDA (Exploratory Data Analysis)**: untuk menggali insight dari data
- **Data Preprocessing**: membersihkan dan menyiapkan data
- **Modeling**:
  - Supervised: Random Forest untuk klasifikasi kelulusan
  - Unsupervised: K-Means untuk clustering siswa

### 📊 Manfaat Bisnis

- Membantu pengajar atau manajemen dalam melakukan intervensi dini
- Meningkatkan tingkat kelulusan dengan strategi yang lebih terarah
"""))
# Out:
# ### 🌍 Latar Belakang Masalah
#
# Dalam dunia pendidikan, penting bagi lembaga pendidikan untuk memahami faktor-faktor apa saja yang dapat mempengaruhi kelulusan siswa. Dengan memanfaatkan data performa akademik, kita dapat membangun sistem prediksi kelulusan secara otomatis.
#
# ### 🎟️ Tujuan Proyek
#
# 1. Mengidentifikasi faktor penting yang mempengaruhi kelulusan siswa.
# 2. Membangun model klasifikasi untuk memprediksi apakah siswa akan *lulus* atau *tidak*.
# 3. Mengelompokkan siswa berdasarkan pola performa mereka (clustering).
#
# ### 🔧 Metode yang Digunakan
#
# - **EDA (Exploratory Data Analysis)**: untuk menggali insight dari data
# - **Data Preprocessing**: membersihkan dan menyiapkan data
# - **Modeling**:
#   - Supervised: Random Forest untuk klasifikasi kelulusan
#   - Unsupervised: K-Means untuk clustering siswa
#
# ### 📊 Manfaat Bisnis
#
# - Membantu pengajar atau manajemen dalam melakukan intervensi dini
# ...
